# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("D:/Data Analysis/adm_data.csv")
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df.shape
# Out:
# (400, 9)

# %%
df.size
# Out:
# 3600

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
#Finding correlation with data
df.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.097526    -0.147932          -0.169948
# GRE Score           -0.097526   1.000000     0.835977           0.668976
# TOEFL Score         -0.147932   0.835977     1.000000           0.695590
# University Rating   -0.169948   0.668976     0.695590           1.000000
# SOP                 -0.166932   0.612831     0.657981           0.734523
# LOR                 -0.088221   0.557555     0.567721           0.660123
# CGPA                -0.045608   0.833060     0.828417           0.746479
# Research            -0.063138   0.580391     0.489858           0.447783
# Chance of Admit      0.042336   0.802610     0.791594           0.711250
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.166932 -0.088221 -0.045608 -0.063138          0.042336
# GRE Score          0.612831  0.557555  0.833060  0.580391          0.802610
# ...

# %%
# making a correlation matrix to find the relation between the columns
plt.figure(figsize=(10,10))
correlation=df.corr()
sns.heatmap(correlation,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# making a correlation matrix to find the relation between the columns
admit_chance = df.corr()['Chance of Admit ']
admit_chance
# Out:
# Serial No.           0.042336
# GRE Score            0.802610
# TOEFL Score          0.791594
# University Rating    0.711250
# SOP                  0.675732
# LOR                  0.669889
# CGPA                 0.873289
# Research             0.553202
# Chance of Admit      1.000000
# Name: Chance of Admit , dtype: float64

# %%
admit_chance=pd.DataFrame(admit_chance)
admit_chance
# Out:
#                    Chance of Admit
# Serial No.                 0.042336
# GRE Score                  0.802610
# TOEFL Score                0.791594
# University Rating          0.711250
# SOP                        0.675732
# LOR                        0.669889
# CGPA                       0.873289
# Research                   0.553202
# Chance of Admit            1.000000

# %%
admit_chance = admit_chance.drop(['Chance of Admit ','Serial No.'])
admit_chance
# Out:
#                    Chance of Admit
# GRE Score                  0.802610
# TOEFL Score                0.791594
# University Rating          0.711250
# SOP                        0.675732
# LOR                        0.669889
# CGPA                       0.873289
# Research                   0.553202

# %%
# Plotting heatmap for 'Chance of Admit ' vs all other columns
sns.heatmap(admit_chance,annot=True,cmap='crest')
# Out:
# <AxesSubplot:>

# %%
# MULTIREGRESSION MODEL
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
x=df.iloc[:,:-1].values  #input data cols
x
# Out:
# array([[  1.  , 337.  , 118.  , ...,   4.5 ,   9.65,   1.  ],
#        [  2.  , 324.  , 107.  , ...,   4.5 ,   8.87,   1.  ],
#        [  3.  , 316.  , 104.  , ...,   3.5 ,   8.  ,   1.  ],
#        ...,
#        [398.  , 330.  , 116.  , ...,   4.5 ,   9.45,   1.  ],
#        [399.  , 312.  , 103.  , ...,   4.  ,   8.78,   0.  ],
#        [400.  , 333.  , 117.  , ...,   4.  ,   9.66,   1.  ]])

# %%
y=df.iloc[:,-1].values #outputdata cols
y
# Out:
# array([0.92, 0.76, 0.72, 0.8 , 0.65, 0.9 , 0.75, 0.68, 0.5 , 0.45, 0.52,
#        0.84, 0.78, 0.62, 0.61, 0.54, 0.66, 0.65, 0.63, 0.62, 0.64, 0.7 ,
#        0.94, 0.95, 0.97, 0.94, 0.76, 0.44, 0.46, 0.54, 0.65, 0.74, 0.91,
#        0.9 , 0.94, 0.88, 0.64, 0.58, 0.52, 0.48, 0.46, 0.49, 0.53, 0.87,
#        0.91, 0.88, 0.86, 0.89, 0.82, 0.78, 0.76, 0.56, 0.78, 0.72, 0.7 ,
#        0.64, 0.64, 0.46, 0.36, 0.42, 0.48, 0.47, 0.54, 0.56, 0.52, 0.55,
#        0.61, 0.57, 0.68, 0.78, 0.94, 0.96, 0.93, 0.84, 0.74, 0.72, 0.74,
#        0.64, 0.44, 0.46, 0.5 , 0.96, 0.92, 0.92, 0.94, 0.76, 0.72, 0.66,
#        0.64, 0.74, 0.64, 0.38, 0.34, 0.44, 0.36, 0.42, 0.48, 0.86, 0.9 ,
#        0.79, 0.71, 0.64, 0.62, 0.57, 0.74, 0.69, 0.87, 0.91, 0.93, 0.68,
#        0.61, 0.69, 0.62, 0.72, 0.59, 0.66, 0.56, 0.45, 0.47, 0.71, 0.94,
#        0.94, 0.57, 0.61, 0.57, 0.64, 0.85, 0.78, 0.84, 0.92, 0.96, 0.77,
#        0.71, 0.79, 0.89, 0.82, 0.76, 0.71, 0.8 , 0.78, 0.84, 0.9 , 0.92,
# ...

# %%
#Set as Training data and Testing data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)
y_test
# Out:
# array([0.69, 0.57, 0.72, 0.96, 0.88, 0.82, 0.68, 0.89, 0.94, 0.64, 0.96,
#        0.88, 0.76, 0.69, 0.67, 0.81, 0.83, 0.94, 0.65, 0.42, 0.65, 0.79,
#        0.63, 0.77, 0.65, 0.77, 0.8 , 0.58, 0.36, 0.76, 0.8 , 0.7 , 0.86,
#        0.87, 0.92, 0.78, 0.54, 0.78, 0.93, 0.84, 0.47, 0.49, 0.83, 0.7 ,
#        0.8 , 0.74, 0.91, 0.95, 0.49, 0.61, 0.64, 0.58, 0.7 , 0.62, 0.78,
#        0.94, 0.66, 0.62, 0.54, 0.85, 0.8 , 0.95, 0.71, 0.66, 0.69, 0.82,
#        0.73, 0.84, 0.63, 0.72, 0.8 , 0.81, 0.66, 0.96, 0.64, 0.68, 0.85,
#        0.82, 0.7 , 0.93, 0.59, 0.79, 0.86, 0.93, 0.71, 0.6 , 0.65, 0.8 ,
#        0.76, 0.34, 0.79, 0.92, 0.75, 0.78, 0.89, 0.38, 0.47, 0.52, 0.89,
#        0.72, 0.67, 0.89, 0.64, 0.64, 0.74, 0.61, 0.91, 0.86, 0.93, 0.81,
#        0.86, 0.76, 0.42, 0.87, 0.97, 0.48, 0.47, 0.52, 0.64, 0.78])

# %%
#Normalization ---->standardscaler--(values are changed to similar values else higher value be evaluated)
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train) #collect data
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[-0.84679949, -0.02898139,  0.47409116, -0.01253038,  0.64528924,
#          1.1800472 ,  0.34272857,  0.91766294],
#        [ 1.47887947, -0.4700026 , -1.49494012, -1.76678412, -2.40847394,
#         -1.0600424 , -1.92373199, -1.08972474],
#        [ 0.61784566, -0.91102381, -0.34633854, -0.88965725, -0.88159235,
#         -0.50002   , -0.61880015,  0.91766294],
#        [-1.14860516,  1.73510344,  0.80226304,  1.74172336,  1.66321031,
#          1.7400696 ,  2.02540384,  0.91766294],
#        [-1.37939773,  0.50024406,  0.47409116,  1.74172336,  1.66321031,
#          0.6200248 ,  0.89217356,  0.91766294],
#        [ 1.72742531,  0.67665254,  0.47409116, -0.01253038,  0.13632871,
#          0.0600024 ,  0.78915262,  0.91766294],
#        [ 1.3901131 , -1.35204502, -0.51042448, -0.88965725,  0.13632871,
#          0.0600024 , -1.18541529,  0.91766294],
#        [ 1.51438602,  0.67665254,  0.47409116, -0.01253038,  0.13632871,
#         -0.50002   ,  1.09821543,  0.91766294],
# ...

# %%
#Training Model
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=np.round(model.predict(x_test),2)
y_pred
# Out:
# array([0.76, 0.55, 0.66, 0.94, 0.8 , 0.84, 0.62, 0.85, 0.96, 0.53, 1.01,
#        0.86, 0.77, 0.67, 0.76, 0.75, 0.86, 0.93, 0.63, 0.56, 0.56, 0.81,
#        0.7 , 0.73, 0.66, 0.71, 0.79, 0.67, 0.52, 0.73, 0.8 , 0.68, 0.84,
#        0.82, 0.83, 0.8 , 0.56, 0.69, 0.9 , 0.8 , 0.54, 0.54, 0.81, 0.64,
#        0.7 , 0.75, 0.94, 0.93, 0.55, 0.77, 0.63, 0.58, 0.73, 0.62, 0.79,
#        0.93, 0.64, 0.67, 0.62, 0.86, 0.81, 0.97, 0.76, 0.65, 0.55, 0.81,
#        0.62, 0.8 , 0.59, 0.68, 0.8 , 0.73, 0.78, 0.96, 0.63, 0.69, 0.78,
#        0.87, 0.71, 0.95, 0.67, 0.77, 0.87, 0.87, 0.75, 0.53, 0.62, 0.84,
#        0.79, 0.55, 0.71, 0.87, 0.68, 0.83, 0.92, 0.57, 0.51, 0.6 , 0.87,
#        0.73, 0.61, 0.87, 0.62, 0.57, 0.79, 0.66, 0.86, 0.84, 0.9 , 0.81,
#        0.83, 0.67, 0.6 , 0.81, 1.  , 0.55, 0.49, 0.53, 0.58, 0.82])

# %%
#Checking how much predicted value is correct,compared to a actual value
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))
# Out:
# [[0.76 0.69]
#  [0.55 0.57]
#  [0.66 0.72]
#  [0.94 0.96]
#  [0.8  0.88]
#  [0.84 0.82]
#  [0.62 0.68]
#  [0.85 0.89]
#  [0.96 0.94]
#  [0.53 0.64]
#  [1.01 0.96]
#  [0.86 0.88]
#  [0.77 0.76]
#  [0.67 0.69]
#  [0.76 0.67]
#  [0.75 0.81]
#  [0.86 0.83]
#  [0.93 0.94]
#  [0.63 0.65]
#  [0.56 0.42]
#  [0.56 0.65]
#  [0.81 0.79]
#  [0.7  0.63]
#  [0.73 0.77]
#  [0.66 0.65]
#  [0.71 0.77]
#  [0.79 0.8 ]
#  [0.67 0.58]
#  [0.52 0.36]
#  [0.73 0.76]
#  [0.8  0.8 ]
#  [0.68 0.7 ]
#  [0.84 0.86]
#  [0.82 0.87]
#  [0.83 0.92]
#  [0.8  0.78]
#  [0.56 0.54]
#  [0.69 0.78]
#  [0.9  0.93]
#  [0.8  0.84]
#  [0.54 0.47]
#  [0.54 0.49]
#  [0.81 0.83]
#  [0.64 0.7 ]
#  [0.7  0.8 ]
#  [0.75 0.74]
#  [0.94 0.91]
#  [0.93 0.95]
#  [0.55 0.49]
#  [0.77 0.61]
#  [0.63 0.64]
#  [0.58 0.58]
#  [0.73 0.7 ]
#  [0.62 0.62]
#  [0.79 0.78]
#  [0.93 0.94]
#  [0.64 0.66]
#  [0.67 0.62]
#  [0.62 0.54]
#  [0.86 0.85]
#  [0.81 0.8 ]
#  [0.97 0.95]
#  [0.76 0.71]
#  [0.65 0.66]
#  [0.55 0.69]
#  [0.81 0.82]
# ...

# %%
#Mean absolute error
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_pred,y_test)
mae
# Out:
# 0.04766666666666667
